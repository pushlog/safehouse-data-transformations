# %%
###################################################################################
########################## Data Prepartion - Event Generation######################
###################################################################################

# Notes
# Each Data Source will be dowloaded independently




# Initialize Variables
   
# Datafile Name
datafile = "transaction_data.csv"
datetimename = 'datetime'
annoyingColumns = ['_id', datetimename,'_index']
person = False



# Import Libraries
import pandas as pd
from summarizeDataFrame import summarizeDataset
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import sys
import numpy as np





# Need to inlcude for Pots
get_ipython().magic(u'matplotlib inline')

# import Data
df = pd.read_csv(datafile)

# make datetime to datetime format
df[datetimename] = pd.to_datetime(df[datetimename])

# Initialize Scenario count Variable
df['desired_output'] = ""


# Start and endtime data
array = ["2018-03-26 18:16:16.658","2018-03-20 18:16:17.696","2018-03-20 18:16:18.707"]
array2 = ["2018-04-02 18:16:19.732","2018-03-20 18:16:19.732","2018-03-20 18:16:19.732"]



# Create unique identifier for scenario aggregation
count = 1

for i,x in zip(array,array2):
        
    df['desired_output'] = np.where(np.logical_and(df[datetimename] >= pd.to_datetime(i) , df[datetimename] <= pd.to_datetime(x)), count , df['desired_output'])   

    count = count + 1
    

    
#print(df)    
    
# Filter Data for no unique and high unique
if person == True:
    
    df2 = df.loc[:,df.apply(pd.Series.nunique) != int(len(df.index))]
    
else:
    
    do = df.loc[:,'desired_output']
    df1 = df.loc[:,df.apply(pd.Series.nunique) != 1]

    df2 = df1.loc[:,df1.apply(pd.Series.nunique) != int(len(df1.index))]
    
    if 'desired_output' not in df2.columns:
        
        
        
        df2 = pd.concat([do,df2], axis=1)
        
        




# Remove Unessary Columns
if all([item in df2.columns for item in annoyingColumns]):
    
    df3 = df2.drop(annoyingColumns, axis=1)
    
else:
    
    df3 = df2



# Get names of column aggregation    
names = list(df3)
if 'desired_output' in names:
    
    names.remove('desired_output')

else:
    
    print("Scenario Not in Dataset")
    print(list(df2))
    sys.exit()
    

        
#print(df3)      

# Create Dummy Variable for Dataset
df5 = pd.get_dummies(df3,columns=names)
df5.index = df[datetimename]

#df6=df5.resample("5T").count()

df6 =df5.groupby(['desired_output'])[list(df5)].count()




# df2  = df1.groupby(['_source.device']).agg({'_source.action': [ min , max ,'first', 'nunique','count']})



#summarizeDataset(df3)


#print(df1.head())

#print(list(df4))
#print(type(names1))
#print(df5.head())
print(df6.head())
# Out:
#                     desired_output  _index_domoticz-2018-03-19  \
# datetime
# 2018-03-19 08:49:05                                          1
# 2018-03-19 08:49:08                                          1
# 2018-03-19 08:50:36                                          1
# 2018-03-19 08:50:39                                          1
# 2018-03-19 08:52:38                                          1
#
#                      _index_domoticz-2018-03-20  _index_domoticz-2018-03-21  \
# datetime
# 2018-03-19 08:49:05                           0                           0
# 2018-03-19 08:49:08                           0                           0
# 2018-03-19 08:50:36                           0                           0
# 2018-03-19 08:50:39                           0                           0
# 2018-03-19 08:52:38                           0                           0
#
#                      _index_domoticz-2018-03-22  _index_domoticz-2018-03-23  \
# datetime
# 2018-03-19 08:49:05                           0                           0
# 2018-03-19 08:49:08                           0                           0
# 2018-03-19 08:50:36                           0                           0
# 2018-03-19 08:50:39                           0                           0
# 2018-03-19 08:52:38                           0                           0
#
#                      _index_domoticz-2018-03-24  _index_domoticz-2018-03-25  \
# datetime
# 2018-03-19 08:49:05                           0                           0
# 2018-03-19 08:49:08                           0                           0
# 2018-03-19 08:50:36                           0                           0
# 2018-03-19 08:50:39                           0                           0
# 2018-03-19 08:52:38                           0                           0
#
#                      _index_domoticz-2018-03-26  _index_domoticz-2018-03-27  \
# datetime
# 2018-03-19 08:49:05                           0                           0
# 2018-03-19 08:49:08                           0                           0
# 2018-03-19 08:50:36                           0                           0
# 2018-03-19 08:50:39                           0                           0
# 2018-03-19 08:52:38                           0                           0
#
#                                       ...                    devicename_Lamp  \
# datetime                              ...
# 2018-03-19 08:49:05                   ...                                  0
# 2018-03-19 08:49:08                   ...                                  0
# 2018-03-19 08:50:36                   ...                                  0
# 2018-03-19 08:50:39                   ...                                  0
# 2018-03-19 08:52:38                   ...                                  0
#
#                      devicename_Lock1  devicename_MotionSensorRoom1  \
# datetime
# 2018-03-19 08:49:05                 0                             0
# 2018-03-19 08:49:08                 0                             0
# 2018-03-19 08:50:36                 0                             0
# 2018-03-19 08:50:39                 0                             0
# 2018-03-19 08:52:38                 0                             0
#
#                      devicename_Plug  devicename_Room  devicename_Room1  \
# datetime
# 2018-03-19 08:49:05                0                0                 0
# 2018-03-19 08:49:08                0                0                 0
# 2018-03-19 08:50:36                0                0                 0
# 2018-03-19 08:50:39                0                0                 0
# 2018-03-19 08:52:38                0                0                 0
#
#                      devicename_Sensor  devicename_Smart  \
# datetime
# 2018-03-19 08:49:05                  0                 0
# 2018-03-19 08:49:08                  0                 0
# 2018-03-19 08:50:36                  0                 0
# 2018-03-19 08:50:39                  0                 0
# 2018-03-19 08:52:38                  0                 0
#
#                      devicename_swx-u-range-sensor-light-1  \
# datetime
# 2018-03-19 08:49:05                                      0
# 2018-03-19 08:49:08                                      0
# 2018-03-19 08:50:36                                      1
# 2018-03-19 08:50:39                                      1
# 2018-03-19 08:52:38                                      1
#
#                      devicename_swx-u-range-sensor-motion-1
# datetime
# 2018-03-19 08:49:05                                       0
# 2018-03-19 08:49:08                                       0
# 2018-03-19 08:50:36                                       0
# 2018-03-19 08:50:39                                       0
# 2018-03-19 08:52:38                                       0
#
# [5 rows x 86 columns]
#                      desired_output  _index_domoticz-2018-03-19  \
# datetime
# 2018-03-19 08:45:00               2                           2
# 2018-03-19 08:50:00               4                           4
# 2018-03-19 08:55:00               0                           0
# 2018-03-19 09:00:00               0                           0
# 2018-03-19 09:05:00               2                           2
#
#                      _index_domoticz-2018-03-20  _index_domoticz-2018-03-21  \
# datetime
# 2018-03-19 08:45:00                           2                           2
# 2018-03-19 08:50:00                           4                           4
# 2018-03-19 08:55:00                           0                           0
# 2018-03-19 09:00:00                           0                           0
# 2018-03-19 09:05:00                           2                           2
#
#                      _index_domoticz-2018-03-22  _index_domoticz-2018-03-23  \
# datetime
# 2018-03-19 08:45:00                           2                           2
# 2018-03-19 08:50:00                           4                           4
# 2018-03-19 08:55:00                           0                           0
# 2018-03-19 09:00:00                           0                           0
# 2018-03-19 09:05:00                           2                           2
#
#                      _index_domoticz-2018-03-24  _index_domoticz-2018-03-25  \
# datetime
# 2018-03-19 08:45:00                           2                           2
# 2018-03-19 08:50:00                           4                           4
# 2018-03-19 08:55:00                           0                           0
# 2018-03-19 09:00:00                           0                           0
# 2018-03-19 09:05:00                           2                           2
#
#                      _index_domoticz-2018-03-26  _index_domoticz-2018-03-27  \
# datetime
# 2018-03-19 08:45:00                           2                           2
# 2018-03-19 08:50:00                           4                           4
# 2018-03-19 08:55:00                           0                           0
# 2018-03-19 09:00:00                           0                           0
# 2018-03-19 09:05:00                           2                           2
#
#                                       ...                    devicename_Lamp  \
# datetime                              ...
# 2018-03-19 08:45:00                   ...                                  2
# 2018-03-19 08:50:00                   ...                                  4
# 2018-03-19 08:55:00                   ...                                  0
# 2018-03-19 09:00:00                   ...                                  0
# 2018-03-19 09:05:00                   ...                                  2
#
#                      devicename_Lock1  devicename_MotionSensorRoom1  \
# datetime
# 2018-03-19 08:45:00                 2                             2
# 2018-03-19 08:50:00                 4                             4
# 2018-03-19 08:55:00                 0                             0
# 2018-03-19 09:00:00                 0                             0
# 2018-03-19 09:05:00                 2                             2
#
#                      devicename_Plug  devicename_Room  devicename_Room1  \
# datetime
# 2018-03-19 08:45:00                2                2                 2
# 2018-03-19 08:50:00                4                4                 4
# 2018-03-19 08:55:00                0                0                 0
# 2018-03-19 09:00:00                0                0                 0
# 2018-03-19 09:05:00                2                2                 2
#
#                      devicename_Sensor  devicename_Smart  \
# datetime
# 2018-03-19 08:45:00                  2                 2
# 2018-03-19 08:50:00                  4                 4
# 2018-03-19 08:55:00                  0                 0
# 2018-03-19 09:00:00                  0                 0
# 2018-03-19 09:05:00                  2                 2
#
#                      devicename_swx-u-range-sensor-light-1  \
# datetime
# 2018-03-19 08:45:00                                      2
# 2018-03-19 08:50:00                                      4
# 2018-03-19 08:55:00                                      0
# 2018-03-19 09:00:00                                      0
# 2018-03-19 09:05:00                                      2
#
#                      devicename_swx-u-range-sensor-motion-1
# datetime
# 2018-03-19 08:45:00                                       2
# 2018-03-19 08:50:00                                       4
# 2018-03-19 08:55:00                                       0
# 2018-03-19 09:00:00                                       0
# 2018-03-19 09:05:00                                       2
#
# [5 rows x 86 columns]
