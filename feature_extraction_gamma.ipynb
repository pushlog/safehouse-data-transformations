# %%
import glob

import numpy as np
import pandas as pd
import featuretools as ft

# %%
npy_files = glob.glob("data/raw/*.npy")

# %%
gamma_npy = [f for f in npy_files if 'gamma' in f and 'colnames' not in f]

# %%
gamma_colnames = np.load('data/raw/gamma_df_colnames.npy')

# %%
gamma_df = pd.DataFrame()
for file in gamma_npy:
    gamma_df = pd.concat([pd.DataFrame(np.load(file)), gamma_df])
gamma_df.columns = list(gamma_colnames)

# %%
gamma_df.shape
# Out:
# (403950, 13)

# %%
gamma_df.head().transpose()
# Out:
#                                             0                           1  \
# _id                      FdWTbmIBcKmh5GBKiUuE        FtWTbmIBcKmh5GBKiUua
# _index                                gammarf                     gammarf
# _score                                      1                           1
# _source.alt                            16.695                      22.759
# _source.epv                            48.968                      34.643
# _source.epx                            10.934                       9.091
# _source.epy                            10.645                       8.616
# _source.freq                       2417000000                  2426000000
# _source.lat                      27.956522393                27.956503568
# _source.lng                     -82.437600713               -82.437424729
# _source.module                              1                           1
# _source.protocol                            1                           1
# _source.pwr                          -41.9534                    -43.5154
# _source.rand                         f2dc0b57                    b50c5751
# _source.sign                     bdfac006950d                ddfaf66ed87a
# _source.stationid                range_outer2                  range_core
# _source.timestamp  2018-03-28T21:46:25.483635  2018-03-28T21:46:25.520671
# _type                                    asdf                        asdf
# DateTime           2018-03-28 21:46:25.483635  2018-03-28 21:46:25.520671
#
#                                             2                           3  \
# _id                      F9WTbmIBcKmh5GBKiUvd        GNWTbmIBcKmh5GBKiksk
# _index                                gammarf                     gammarf
# _score                                      1                           1
# _source.alt                            16.695                      16.695
# _source.epv                            48.968                      48.968
# _source.epx                            10.934                      10.934
# _source.epy                            10.645                      10.645
# _source.freq                       2426000000                  2431000000
# _source.lat                      27.956522393                27.956522393
# _source.lng                     -82.437600713               -82.437600713
# _source.module                              1                           1
# _source.protocol                            1                           1
# _source.pwr                          -32.9212                    -43.5126
# _source.rand                         86be43ec                    7d3738d4
# _source.sign                     6b81966d3646                e0a781815c35
# _source.stationid                range_outer2                range_outer2
# _source.timestamp  2018-03-28T21:46:25.562015  2018-03-28T21:46:25.633459
# _type                                    asdf                        asdf
# DateTime           2018-03-28 21:46:25.562015  2018-03-28 21:46:25.633459
#
#                                             4
# _id                      KNWTbmIBcKmh5GBKiktZ
# _index                                gammarf
# _score                                      1
# _source.alt                            16.695
# _source.epv                            48.968
# _source.epx                            10.934
# _source.epy                            10.645
# _source.freq                       2432000000
# _source.lat                      27.956522393
# _source.lng                     -82.437600713
# _source.module                              1
# _source.protocol                            1
# _source.pwr                          -38.1887
# _source.rand                         9b50e1af
# _source.sign                     3e3bea72ba66
# _source.stationid                range_outer2
# _source.timestamp  2018-03-28T21:46:25.703903
# _type                                    asdf
# DateTime           2018-03-28 21:46:25.703903

# %%
gamma_df = gamma_df.drop(["_index","_score","_type","DateTime","_source.module","_source.protocol"], axis=1)

# %%
gamma_df.head().transpose()
# Out:
#                                             0                           1  \
# _id                      FdWTbmIBcKmh5GBKiUuE        FtWTbmIBcKmh5GBKiUua
# _source.alt                            16.695                      22.759
# _source.epv                            48.968                      34.643
# _source.epx                            10.934                       9.091
# _source.epy                            10.645                       8.616
# _source.freq                       2417000000                  2426000000
# _source.lat                      27.956522393                27.956503568
# _source.lng                     -82.437600713               -82.437424729
# _source.pwr                          -41.9534                    -43.5154
# _source.rand                         f2dc0b57                    b50c5751
# _source.sign                     bdfac006950d                ddfaf66ed87a
# _source.stationid                range_outer2                  range_core
# _source.timestamp  2018-03-28T21:46:25.483635  2018-03-28T21:46:25.520671
#
#                                             2                           3  \
# _id                      F9WTbmIBcKmh5GBKiUvd        GNWTbmIBcKmh5GBKiksk
# _source.alt                            16.695                      16.695
# _source.epv                            48.968                      48.968
# _source.epx                            10.934                      10.934
# _source.epy                            10.645                      10.645
# _source.freq                       2426000000                  2431000000
# _source.lat                      27.956522393                27.956522393
# _source.lng                     -82.437600713               -82.437600713
# _source.pwr                          -32.9212                    -43.5126
# _source.rand                         86be43ec                    7d3738d4
# _source.sign                     6b81966d3646                e0a781815c35
# _source.stationid                range_outer2                range_outer2
# _source.timestamp  2018-03-28T21:46:25.562015  2018-03-28T21:46:25.633459
#
#                                             4
# _id                      KNWTbmIBcKmh5GBKiktZ
# _source.alt                            16.695
# _source.epv                            48.968
# _source.epx                            10.934
# _source.epy                            10.645
# _source.freq                       2432000000
# _source.lat                      27.956522393
# _source.lng                     -82.437600713
# _source.pwr                          -38.1887
# _source.rand                         9b50e1af
# _source.sign                     3e3bea72ba66
# _source.stationid                range_outer2
# _source.timestamp  2018-03-28T21:46:25.703903

# %% [markdown]
# ### Represent data with EntitySets

# %%
from featuretools.variable_types import Categorical, LatLong, Numeric
from featuretools.primitives import Latitude, Longitude

# %%
es = ft.EntitySet(id="gamma")

# %%
es = es.entity_from_dataframe(entity_id="gamma",
                             dataframe=gamma_df,
                             index="_id",
                             time_index="_source.timestamp",
                             variable_types={"_source.lat": LatLong,
                                             "_source.lng": LatLong,
                                             "_source.alt": Numeric,
                                             "_source.epv": Numeric,
                                             "_source.epx": Numeric,
                                             "_source.epy": Numeric,
                                             "_source.freq": Numeric,
                                             "_source.pwr": Numeric})

# %%
es
# Out:
# Entityset: gamma
#   Entities:
#     gamma (shape = [403950, 13])
#   Relationships:
#     No relationships

# %%
es["gamma"].variables
# Out:
# [<Variable: _source.lat (dtype = latlong, count = 403950)>,
#  <Variable: _source.epv (dtype = numeric, count = 403950)>,
#  <Variable: _source.alt (dtype = numeric, count = 403950)>,
#  <Variable: _source.rand (dtype = categorical, count = 403950)>,
#  <Variable: _source.epy (dtype = numeric, count = 403950)>,
#  <Variable: _source.stationid (dtype = categorical, count = 403950)>,
#  <Variable: _source.freq (dtype = numeric, count = 403950)>,
#  <Variable: _source.timestamp (dtype: datetime_time_index, format: None)>,
#  <Variable: _source.sign (dtype = categorical, count = 403950)>,
#  <Variable: _source.pwr (dtype = numeric, count = 403950)>,
#  <Variable: _source.epx (dtype = numeric, count = 403950)>,
#  <Variable: _source.lng (dtype = latlong, count = 403950)>,
#  <Variable: _id (dtype = index, count = 403950)>]

# %% [markdown]
# ### Extract feature matrix

# %%
from featuretools.primitives import Count, Month

# %%
feature_matrix, feature_defs = ft.dfs(entityset=es, 
                                      target_entity="gamma",
                                      agg_primitives=[Count],
                                      trans_primitives=[Month],
                                      max_depth=1)

# %%
feature_matrix
# Out:
#                       _source.epx  _source.freq _source.stationid  \
# _id
# ---QcmIBcKmh5GBK0gKp       10.934    2433000000      range_outer2
# ---RcmIBcKmh5GBKlwqr        9.091    2436000000        range_core
# ---RcmIBcKmh5GBKqgv3        9.091    2461000000        range_core
# ---ScmIBcKmh5GBKMRA0       10.934    2416000000      range_outer2
# ---ScmIBcKmh5GBKjRWu       10.934    2438000000      range_outer2
# ---VcmIBcKmh5GBKJDN7       10.934    2433000000      range_outer2
# ---WcmIBcKmh5GBK5kdL       10.934    2142000000      range_outer2
# ---XcmIBcKmh5GBKLEqw        9.091    2468000000        range_core
# ---YcmIBcKmh5GBKjVom        9.091    2443000000        range_core
# ---acmIBcKmh5GBK-Hj6       10.934    2442000000      range_outer2
# ---acmIBcKmh5GBKNm8a        9.091    2443000000        range_core
# ---ccmIBcKmh5GBKx43L        9.091    2441000000        range_core
# ---fcmIBcKmh5GBKCqz6       10.934    2461000000      range_outer2
# ---fcmIBcKmh5GBKMrIn        9.091    2442000000        range_core
# ---fcmIBcKmh5GBKPLO4        9.091    2446000000        range_core
# ---fcmIBcKmh5GBKV7Sl        9.091    2457000000        range_core
# ---hcmIBcKmh5GBKHdUT       10.934    2433000000      range_outer2
# --1-cmIBcKmh5GBKLvSw        9.091    2468000000        range_core
# --10cmIBcKmh5GBK0Huz        9.091    2458000000        range_core
# --11cmIBcKmh5GBK5YiE       10.934    2452000000      range_outer2
# --11cmIBcKmh5GBKeIP0       10.934    2467000000      range_outer2
# --12cmIBcKmh5GBK0ZOx        9.091    2433000000        range_core
# --13cmIBcKmh5GBK-aIf        9.091    2436000000        range_core
# --14cmIBcKmh5GBKsKxA        9.091    2467000000        range_core
# --15cmIBcKmh5GBK2blW       10.934    2437000000      range_outer2
# --15cmIBcKmh5GBKXbNi        9.091    2467000000        range_core
# --16cmIBcKmh5GBK6sfx       10.934    2417000000      range_outer2
# --16cmIBcKmh5GBKBbv9       10.934    2432000000      range_outer2
# --16cmIBcKmh5GBKicKM       11.448    2411000000      range_outer1
# --18cmIBcKmh5GBK6OE4        9.091    2461000000        range_core
# ...                           ...           ...               ...
# zzkNfWIBcKmh5GBKsHdo        9.091    2463000000        range_core
# zzkQfWIBcKmh5GBKwYkU        9.091    2461000000        range_core
# --12cmIBcKmh5GBK0ZOx     09d0f907   -43.995071                         3
# --13cmIBcKmh5GBK-aIf     9889862b   -40.278431                         3
# --14cmIBcKmh5GBKsKxA     add10779   -39.354568                         3
# --15cmIBcKmh5GBK2blW     b1159a62   -43.735474                         3
# --15cmIBcKmh5GBKXbNi     fce94afc   -38.964321                         3
# --16cmIBcKmh5GBK6sfx     0d121469   -42.614372                         3
# --16cmIBcKmh5GBKBbv9     6c62485b   -45.321728                         3
# --16cmIBcKmh5GBKicKM     66f4aac9   -41.420624                         3
# --18cmIBcKmh5GBK6OE4     c921ebc1   -38.917469                         3
# ...                           ...          ...                       ...
# zzkNfWIBcKmh5GBKsHdo     657dcdce   -40.244389                         3
# zzkQfWIBcKmh5GBKwYkU     04bda2fe   -40.090759                         3
# zzkUfWIBcKmh5GBKhJ7z     f0bd8410   -41.640507                         3
# zzn5fGIBcKmh5GBKdgTH     d6e0a298   -37.256271                         3
# zzn8fGIBcKmh5GBKIhMw     0b534b2d   -40.351772                         3
# zzo5fWIBcKmh5GBKW244     dd227aff   -35.839882                         3
# zzovfWIBcKmh5GBKrDdo     fe7c8f36   -32.147842                         3
# zzpDfWIBcKmh5GBKxKlF     9bcaff45   -43.104694                         3
# zzpIfWIBcKmh5GBKCMEA     3069fc03   -30.062811                         3
# zzpJfWIBcKmh5GBKlMrV     95c6bcc8   -42.322403                         3
# zzt-fWIBcKmh5GBKBvPk     61f9b484   -30.342548                         3
# zzt0fWIBcKmh5GBKIbuW     b0baf280   -38.244846                         3
# zzt1fWIBcKmh5GBKaMLu     9bd63dd8   -41.538982                         3
# zzt2fWIBcKmh5GBKrMkH     ee3ebc71   -43.885548                         3
# zzt5fWIBcKmh5GBK0Ntu     456f0bcc   -36.463825                         3
# zztVfWIBcKmh5GBKGgve     41b264e4   -39.236427                         3
# zzt_fWIBcKmh5GBKfvuE     c9173db9   -25.783123                         3
# zztgfWIBcKmh5GBKY0tl     bae12c9f   -35.875847                         3
# zztvfWIBcKmh5GBKuKIa     21c29c88   -38.969978                         3
# zztzfWIBcKmh5GBKd7er     7df25acc   -40.351799                         3
# zzyBfWIBcKmh5GBKsggI     b66bfb53   -39.885921                         3
# zzyKfWIBcKmh5GBK6zwd     ba9acf73   -42.196247                         3
# zzyKfWIBcKmh5GBKNzgW     06290090   -42.841595                         3
# zzyPfWIBcKmh5GBK8Vks     4147faa0   -37.298752                         3
# zzyZfWIBcKmh5GBKdo_k     f1a00af3   -37.383247                         3
# zzybfWIBcKmh5GBKopzi     109afb24   -39.704220                         3
# zzydfWIBcKmh5GBK_akF     6e0bebcc   -34.448063                         3
# zzyhfWIBcKmh5GBKar01     51a04c45   -39.207253                         3
# zzyqfWIBcKmh5GBK7_Mw     0695c3da   -31.668552                         3
# zzyrfWIBcKmh5GBKevZ2     0cec0df1   -40.293144                         3
#
# [403950 rows x 10 columns]
