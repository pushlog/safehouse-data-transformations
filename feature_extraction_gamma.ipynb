# %%
import glob

import numpy as np
import pandas as pd
import featuretools as ft

# %%
npy_files = glob.glob("data/raw/*.npy")

# %%
gamma_npy = [f for f in npy_files if 'gamma' in f and 'colnames' not in f]

# %%
gamma_colnames = np.load('data/raw/gamma_df_colnames.npy')

# %%
gamma_df = pd.DataFrame()
for file in gamma_npy:
    gamma_df = pd.concat([pd.DataFrame(np.load(file)), gamma_df])
gamma_df.columns = list(gamma_colnames)

# %%
gamma_df.shape
# Out:
# (1125615, 19)

# %%
gamma_df.head().transpose()
# Out:
#                                             0                           1  \
# _id                      hBzcd2IBcKmh5GBKv1Fy        hRzcd2IBcKmh5GBKv1G6
# _index                                gammarf                     gammarf
# _score                                      1                           1
# _source.alt                            20.252                      20.252
# _source.epv                            34.643                      34.643
# _source.epx                             9.091                       9.091
# _source.epy                             8.616                       8.616
# _source.freq                       2417000000                  2433000000
# _source.lat                       27.95652579                 27.95652579
# _source.lng                     -82.437450939               -82.437450939
# _source.module                              1                           1
# _source.protocol                            1                           1
# _source.pwr                          -35.0759                    -42.0609
# _source.rand                         71fffcfd                    26a68d2e
# _source.sign                     56bcb9ac67b8                f547bb922aa1
# _source.stationid                  range_core                  range_core
# _source.timestamp  2018-03-30T17:02:58.351536  2018-03-30T17:02:58.432922
# _type                                    asdf                        asdf
# DateTime           2018-03-30 17:02:58.351536  2018-03-30 17:02:58.432922
#
#                                             2                           3  \
# _id                      hhzcd2IBcKmh5GBKv1Hq        hxzcd2IBcKmh5GBKwFE0
# _index                                gammarf                     gammarf
# _score                                      1                           1
# _source.alt                            20.252                      20.252
# _source.epv                            34.643                      34.643
# _source.epx                             9.091                       9.091
# _source.epy                             8.616                       8.616
# _source.freq                       2441000000                  2442000000
# _source.lat                       27.95652579                 27.95652579
# _source.lng                     -82.437450939               -82.437450939
# _source.module                              1                           1
# _source.protocol                            1                           1
# _source.pwr                          -36.6234                     -45.408
# _source.rand                         c51d307c                    376968c0
# _source.sign                     2144ddc27e48                49ee362df7a1
# _source.stationid                  range_core                  range_core
# _source.timestamp  2018-03-30T17:02:58.500878  2018-03-30T17:02:58.545783
# _type                                    asdf                        asdf
# DateTime           2018-03-30 17:02:58.500878  2018-03-30 17:02:58.545783
#
#                                             4
# _id                      PBzcd2IBcKmh5GBK4FJH
# _index                                gammarf
# _score                                      1
# _source.alt                            20.252
# _source.epv                            34.643
# _source.epx                             9.091
# _source.epy                             8.616
# _source.freq                       2411000000
# _source.lat                       27.95652579
# _source.lng                     -82.437450939
# _source.module                              1
# _source.protocol                            1
# _source.pwr                          -39.1471
# _source.rand                         65253cba
# _source.sign                     c9f03a1253e2
# _source.stationid                  range_core
# _source.timestamp  2018-03-30T17:03:06.781078
# _type                                    asdf
# DateTime           2018-03-30 17:03:06.781078

# %%
gamma_df = gamma_df.drop(["_score","_type","DateTime","_source.module","_source.protocol"], axis=1)

# %%
gamma_df["new_index"] = [i for i in range(gamma_df.shape[0])]

# %%
gamma_df.head().transpose()
# Out:
#                                             0                           1  \
# _id                      hBzcd2IBcKmh5GBKv1Fy        hRzcd2IBcKmh5GBKv1G6
# _index                                gammarf                     gammarf
# _source.alt                            20.252                      20.252
# _source.epv                            34.643                      34.643
# _source.epx                             9.091                       9.091
# _source.epy                             8.616                       8.616
# _source.freq                       2417000000                  2433000000
# _source.lat                       27.95652579                 27.95652579
# _source.lng                     -82.437450939               -82.437450939
# _source.pwr                          -35.0759                    -42.0609
# _source.rand                         71fffcfd                    26a68d2e
# _source.sign                     56bcb9ac67b8                f547bb922aa1
# _source.stationid                  range_core                  range_core
# _source.timestamp  2018-03-30T17:02:58.351536  2018-03-30T17:02:58.432922
# new_index                                   0                           1
#
#                                             2                           3  \
# _id                      hhzcd2IBcKmh5GBKv1Hq        hxzcd2IBcKmh5GBKwFE0
# _index                                gammarf                     gammarf
# _source.alt                            20.252                      20.252
# _source.epv                            34.643                      34.643
# _source.epx                             9.091                       9.091
# _source.epy                             8.616                       8.616
# _source.freq                       2441000000                  2442000000
# _source.lat                       27.95652579                 27.95652579
# _source.lng                     -82.437450939               -82.437450939
# _source.pwr                          -36.6234                     -45.408
# _source.rand                         c51d307c                    376968c0
# _source.sign                     2144ddc27e48                49ee362df7a1
# _source.stationid                  range_core                  range_core
# _source.timestamp  2018-03-30T17:02:58.500878  2018-03-30T17:02:58.545783
# new_index                                   2                           3
#
#                                             4
# _id                      PBzcd2IBcKmh5GBK4FJH
# _index                                gammarf
# _source.alt                            20.252
# _source.epv                            34.643
# _source.epx                             9.091
# _source.epy                             8.616
# _source.freq                       2411000000
# _source.lat                       27.95652579
# _source.lng                     -82.437450939
# _source.pwr                          -39.1471
# _source.rand                         65253cba
# _source.sign                     c9f03a1253e2
# _source.stationid                  range_core
# _source.timestamp  2018-03-30T17:03:06.781078
# new_index                                   4

# %% [markdown]
# ### Represent data with EntitySets

# %%
from featuretools.variable_types import Categorical, LatLong, Numeric
from featuretools.primitives import Latitude, Longitude

# %%
es = ft.EntitySet(id="gamma")

# %%
es = es.entity_from_dataframe(entity_id="gamma",
                             dataframe=gamma_df,
                             index="new_index",
                             time_index="_source.timestamp",
                             variable_types={"_source.lat": LatLong,
                                             "_source.lng": LatLong,
                                             "_source.alt": Numeric,
                                             "_source.epv": Numeric,
                                             "_source.epx": Numeric,
                                             "_source.epy": Numeric,
                                             "_source.freq": Numeric,
                                             "_source.pwr": Numeric})

# %%
es
# Out:
# Entityset: gamma
#   Entities:
#     gamma (shape = [1125615, 15])
#   Relationships:
#     No relationships

# %%
es["gamma"].variables
# Out:
# [<Variable: new_index (dtype = index, count = 1125615)>,
#  <Variable: _source.epx (dtype = numeric, count = 1125615)>,
#  <Variable: _index (dtype = categorical, count = 1125615)>,
#  <Variable: _source.stationid (dtype = categorical, count = 1125615)>,
#  <Variable: _source.lat (dtype = latlong, count = 1125615)>,
#  <Variable: _source.timestamp (dtype: datetime_time_index, format: None)>,
#  <Variable: _source.pwr (dtype = numeric, count = 1125615)>,
#  <Variable: _id (dtype = categorical, count = 1125615)>,
#  <Variable: _source.epv (dtype = numeric, count = 1125615)>,
#  <Variable: _source.epy (dtype = numeric, count = 1125615)>,
#  <Variable: _source.freq (dtype = numeric, count = 1125615)>,
#  <Variable: _source.lng (dtype = latlong, count = 1125615)>,
#  <Variable: _source.alt (dtype = numeric, count = 1125615)>,
#  <Variable: _source.rand (dtype = categorical, count = 1125615)>,
#  <Variable: _source.sign (dtype = categorical, count = 1125615)>]

# %% [markdown]
# ### Extract feature matrix

# %%
from featuretools.primitives import Count, Month

# %%
feature_matrix, feature_defs = ft.dfs(entityset=es, 
                                      target_entity="gamma",
                                      agg_primitives=[Count],
                                      trans_primitives=[Month],
                                      max_depth=1)

# %%
feature_matrix
# Out:
#            _source.epx   _index  _source.alt  _source.freq  _source.epv  \
# new_index
# 0                9.091  gammarf       20.252    2417000000       34.643
# 1                9.091  gammarf       20.252    2433000000       34.643
# 2                9.091  gammarf       20.252    2441000000       34.643
# 3                9.091  gammarf       20.252    2442000000       34.643
# 4                9.091  gammarf       20.252    2411000000       34.643
# 5                9.091  gammarf       19.261    2436000000       34.643
# 6                9.091  gammarf       20.136    2437000000       34.643
# 7                9.091  gammarf       20.136    2438000000       34.643
# 8                9.091  gammarf       20.136    2446000000       34.643
# 9                9.091  gammarf       20.136    2461000000       34.643
# 10               9.091  gammarf       20.136    2463000000       34.643
# 11               9.091  gammarf       19.551    2417000000       34.643
# 12               9.091  gammarf       19.551    2428000000       34.643
# 13               9.091  gammarf       19.551    2458000000       34.643
# 14               9.091  gammarf       19.551    2463000000       34.643
# 15               9.091  gammarf       19.551    2483000000       34.643
# 16               9.091  gammarf       19.551    2484000000       34.643
# 17               9.091  gammarf       19.551    2457000000       34.643
# 18               9.091  gammarf       19.667     469550000       34.643
# 19               9.091  gammarf       18.676    1752000000       34.643
# 20               9.091  gammarf       18.676    2456000000       34.643
# 21               9.091  gammarf       18.676    2457000000       34.643
# 22               9.091  gammarf       18.676    2458000000       34.643
# 23               9.091  gammarf       18.676    2148000000       34.643
# 24               9.091  gammarf       18.676    2426000000       34.643
# 25               9.091  gammarf       18.676    2427000000       34.643
# 26               9.091  gammarf       18.676    2428000000       34.643
# 27               9.091  gammarf       18.676    2452000000       34.643
# 28               9.091  gammarf       18.676    2453000000       34.643
# 29               9.091  gammarf       18.676    2461000000       34.643
# ...                ...      ...          ...           ...          ...
# 1125585          9.091  gammarf       14.115    2463000000       34.643
# 1125586          9.091  gammarf       13.647    2411000000       34.643
# 1125587          9.091  gammarf       13.647    2458000000       34.643
# 1125588          9.091  gammarf       13.647    2406000000       34.643
# 1125589          9.091  gammarf       13.647    2432000000       34.643
# 1125590          9.091  gammarf       13.647    2433000000       34.643
# 1125591          9.091  gammarf       13.647    2436000000       34.643
# 1125592          9.091  gammarf       13.647    2437000000       34.643
# 1125593          9.091  gammarf       13.647    2438000000       34.643
# 1125611     -42.322155  p3rNiGIBcKmh5GBKkjfb        range_core     cc1a4084
# 1125612     -29.287634  qHrNiGIBcKmh5GBKkzcM        range_core     39ce75d9
# 1125613     -37.718834  qXrNiGIBcKmh5GBKkzc8        range_core     8e10938d
# 1125614     -30.046206  qnrNiGIBcKmh5GBKkzeD        range_core     47d2e4db
#
#            _source.sign  _source.epy  MONTH(_source.timestamp)
# new_index
# 0          56bcb9ac67b8        8.616                         3
# 1          f547bb922aa1        8.616                         3
# 2          2144ddc27e48        8.616                         3
# 3          49ee362df7a1        8.616                         3
# 4          c9f03a1253e2        8.616                         3
# 5          439219ad2990        8.616                         3
# 6          4fce020aca0f        8.616                         3
# 7          1e449b8d6bed        8.616                         3
# 8          d39416c2e5bc        8.616                         3
# 9          9137fa0c6482        8.616                         3
# 10         6d3390e09730        8.616                         3
# 11         8d7b8308895c        8.616                         3
# 12         53940c1ed519        8.616                         3
# 13         acfbd1196c6c        8.616                         3
# 14         c8b1293f89a8        8.616                         3
# 15         e81b5968f0da        8.616                         3
# 16         d37778194c4c        8.616                         3
# 17         b11427e16fc4        8.616                         3
# 18         ce0fe1d97097        8.616                         3
# 19         af7f5448b64d        8.616                         3
# 20         081aa69683dc        8.616                         3
# 21         7ae7becf8de4        8.616                         3
# 22         8929ea69e85c        8.616                         3
# 23         af2a4ff0cfd0        8.616                         3
# 24         39207bea814c        8.616                         3
# 25         bb4e348d9a39        8.616                         3
# 26         6fad15be3e22        8.616                         3
# 27         ba29e623c8e1        8.616                         3
# 28         0456b5e4818d        8.616                         3
# 29         c1b601165d0e        8.616                         3
# ...                 ...          ...                       ...
# 1125585    1880732eda34        8.616                         4
# 1125586    3ef8b83d08ce        8.616                         4
# 1125587    a4c6d128b1aa        8.616                         4
# 1125588    6bf0915475a7        8.616                         4
# 1125589    5cc68a03e063        8.616                         4
# 1125590    38a5b261c678        8.616                         4
# 1125591    5e19197d9c6b        8.616                         4
# 1125592    e98a514fc68d        8.616                         4
# 1125593    22d8337cb4b1        8.616                         4
# 1125594    0c5b64df1555        8.616                         4
# 1125595    6120aa278f07        8.616                         4
# 1125596    448d339ef43c        8.616                         4
# 1125597    3729c3e6c883        8.616                         4
# 1125598    0ceb401096cf        8.616                         4
# 1125599    1a313376be74        8.616                         4
# 1125600    e033d3ca8b52        8.616                         4
# 1125601    271c38aae9e5        8.616                         4
# 1125602    8a33ee374a12        8.616                         4
# 1125603    fac0e00f7704        8.616                         4
# 1125604    04cb54487a8e        8.616                         4
# 1125605    64205c5df48f        8.616                         4
# 1125606    faaa369ac9f3        8.616                         4
# 1125607    c6a00efb678e        8.616                         4
# 1125608    5e50659e4e78        8.616                         4
# 1125609    7926085a08db        8.616                         4
# 1125610    d3aae02ac079        8.616                         4
# 1125611    dfc08da7c5df        8.616                         4
# 1125612    0f9f41cb0ae5        8.616                         4
# 1125613    e9a71f1475f2        8.616                         4
# 1125614    c49d4358ee62        8.616                         4
#
# [1125615 rows x 12 columns]
